# %% [markdown]
# # Extracting Cause and Effect to Predict Automotive Accidents
# In this notebook, we will be creating different Machine Learning Models to predict car accident severity (as measured by impact on traffic)

# %% [markdown]
# ### The Problem:
# Car accidents come with a great cost: to the drivers and passengers involved in the accidents, to the individuals who must wait in congested highways, and to the transportation industries at large. These are immense tragedies with costly repercussions. This project seeks to develop a model that will tell us where and under what conditions severe car accidents are likely to occur. This information can then be implemented into solutions that will minimize the total costs of car accidents and hopefully save lives.
#
# The model developed herein will be developed and proposed as valuable information for the transportation company Lyft, Inc. to minimze their insurance claims costs by warning drivers that they are in high-risk situations or directing drivers towards lower-risk route options.

# %% [markdown]
# ### The Data
# Data Source: https://osu.app.box.com/v/us-accidents-june20
#
# Metadata: https://smoosavi.org/datasets/us_accidents
#
# #### Descripion
# This is a countrywide traffic accident dataset, which covers 49 states of the United States. The data was continuously collected from February 2016 thru June 2020, using several data providers, including two APIs which provide streaming traffic event data. These APIs broadcast traffic events captured by a variety of entities, such as the US and state departments of transportation, law enforcement agencies, traffic cameras, and traffic sensors within the road-networks. Currently, there are about 3.5 million accident records in this dataset.
#
# #### Discussion
# This data contains 49 total features that can be thought of as 3 main overarching categories: (1) Location, (2) Weather, and (3) Time of Day. Listed Below.
#
# I will incorporate features that will make the most accurate model possible, while remaining robust and relevant to those features that will make for the best formulation of solutions to the problem of severe car accidents (such as location, weather, and time of day). Since I am trying to discover which features are highly correlated with severe car accidents (and thus presenting a possibility of causality), I will be cleaning my data of any collinearity.
#
# The dataset provides us with the assets necessary to make the following inquiries:
# - Where are severe car accidents most likely to occur?
# - When are severe car accidents most likely to occur?
# - Under what conditions are severe car accidents most likely to occur?
#
# (1) Location:
# - 7-10 - "Exact Location"
# - 7 - Start_Lat
# - 8 - Start_Lng
# - 9 - End_Lat
# - 10 - End_Lng
# - 13-20 - "Address Data"
# - 13 - Number
# - 14 - Street
# - 15 - Side
# - 16 - City
# - 17 - County
# - 18 - State
# - 19 - Zipcode
# - 20 - Country
# - 33-45 - "What exists nearby"
# - 33 - Amenity
# - 34 - Bump
# - 35 - Crossing
# - 36 - Give_Way
# - 37 - Junction
# - 38 - No_Exit
# - 39 - Railway
# - 40 - Roundabout
# - 41 - Station
# - 42 - Stop
# - 43 - Traffic_Calming
# - 44 - Traffic_Signal
# - 45 - Turning_Loop
#
# (2) Weather:
# - 23 - Weather_Timestamp
# - 24 - Temperature(F)
# - 25 - Wind_Chill(F)
# - 26 - Humidity(%)
# - 27 - Pressure(in)
# - 28 - Visibility
# - 29 - Wind_Direction
# - 30 - Wind_Speed(mph)
# - 31 - Precipitation(in)
# - 32 - Weather_Condition
#
# (3) Time of Day:
# - 5 - Start_Time
# - 6 - End_Time
# - 21 - Timezone
# - 23 - Weather_Timestamp
# - 46 - Sunrise_Sunset
# - 47 - Civil_Twilight
# - 48 - Nautical_Twilight
# - 49 - Astronomical_Twilight
#
# Target Variable(s):
# - 4 - Severity
# - 11 - Distance(mi)
#
# Extra Information:
# - 12 - Description
# - 3 - TMC ("Traffic Message Channel" code)
# - 2 - Source
# - 22 - Airport_Code
#
# ##### Acknowledgements:
# Moosavi, Sobhan, Mohammad Hossein Samavatian, Srinivasan Parthasarathy, and Rajiv Ramnath. “A Countrywide Traffic
#     Accident Dataset.”, arXiv preprint arXiv:1906.05409 (2019).
#
# Moosavi, Sobhan, Mohammad Hossein Samavatian, Srinivasan Parthasarathy, Radu Teodorescu, and Rajiv Ramnath. “Accident
#     Risk Prediction based on Heterogeneous Sparse Data: New Dataset and Insights.” In proceedings of the 27th ACM
#     SIGSPATIAL International Conference on Advances in Geographic Information Systems, ACM, 2019.

# %% [markdown]
# # Data Wrangling

# %%
import os

os.chdir('/')
os.chdir('Users/petermcmaster/Desktop')
os.getcwd()
# Out:
# '/Users/petermcmaster/Desktop'

# %%
import pandas as pd

data = pd.read_csv("US_Accidents.csv")
pd.set_option('display.max_columns', None)
data.head(40)
# Out:
#       ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0    A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1    A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2    A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3    A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4    A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
# 5    A-6  MapQuest  201.0         3  2016-02-08 07:44:26  2016-02-08 08:14:26
# 6    A-7  MapQuest  201.0         2  2016-02-08 07:59:35  2016-02-08 08:29:35
# 7    A-8  MapQuest  201.0         3  2016-02-08 07:59:58  2016-02-08 08:29:58
# 8    A-9  MapQuest  201.0         2  2016-02-08 08:00:40  2016-02-08 08:30:40
# 9   A-10  MapQuest  201.0         3  2016-02-08 08:10:04  2016-02-08 08:40:04
# 10  A-11  MapQuest  201.0         3  2016-02-08 08:14:42  2016-02-08 08:44:42
# ...

# %% [markdown]
# Create a Los Angeles subset for testing methods. DROP UNNECESSARY COLUMNS.

# %%
# Make a smaller dataset for just LA

dfla = data.loc[data["City"]=="Los Angeles"]
dfla.shape
# Out:
# (79170, 49)

# %%
dfla.dtypes
# Out:
# ID                        object
# Source                    object
# TMC                      float64
# Severity                   int64
# Start_Time                object
# End_Time                  object
# Start_Lat                float64
# Start_Lng                float64
# End_Lat                  float64
# End_Lng                  float64
# Distance(mi)             float64
# Description               object
# Number                   float64
# Street                    object
# Side                      object
# City                      object
# County                    object
# State                     object
# Zipcode                   object
# Country                   object
# Timezone                  object
# Airport_Code              object
# Weather_Timestamp         object
# Temperature(F)           float64
# Wind_Chill(F)            float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# ...

# %%
# Drop unnecessary columns from dfla
dfla.drop(["ID", "Source", "TMC", "End_Time", "End_Lat", "End_Lng", 
           "Distance(mi)", "Description", "Number", "Country", 
           "Airport_Code", "Weather_Timestamp", "Wind_Chill(F)", 
           "Wind_Direction", "Civil_Twilight", "Nautical_Twilight"], axis=1, inplace=True)
dfla.head(10)
# Out:
# /Users/petermcmaster/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#        Severity           Start_Time  Start_Lat   Start_Lng  \
# 42866         2  2016-06-21 10:46:30  34.078926 -118.289040
# 42867         3  2016-06-21 10:49:21  34.091179 -118.239471
# 42881         3  2016-06-21 10:51:45  34.037239 -118.309074
# 42883         3  2016-06-21 10:56:24  34.027458 -118.274490
# 42898         3  2016-06-21 11:30:46  33.947544 -118.279434
# 42912         3  2016-06-21 11:59:09  34.034721 -118.344635
# 42914         3  2016-06-21 12:00:06  33.947437 -118.279312
# 42915         2  2016-06-21 12:12:04  34.069759 -118.236176
# 42916         2  2016-06-21 12:11:43  33.957775 -118.231056
# ...

# %% [markdown]
# Set POI Booleans to Binaries

# %%
# Amenity
dfla["Amenity"] = dfla["Amenity"].astype(int)
# Bump
dfla["Bump"] = dfla["Bump"].astype(int)
# Crossing
dfla["Crossing"] = dfla["Crossing"].astype(int)
# Give_Way
dfla["Give_Way"] = dfla["Give_Way"].astype(int)
# Junction
dfla["Junction"] = dfla["Junction"].astype(int)
# No_Exit
dfla["No_Exit"] = dfla["No_Exit"].astype(int)
# Railway
dfla["Railway"] = dfla["Railway"].astype(int)
# Roundabout
dfla["Roundabout"] = dfla["Roundabout"].astype(int)
# Station
dfla["Station"] = dfla["Station"].astype(int)
# Stop
dfla["Stop"] = dfla["Stop"].astype(int)
# Traffic_Calming
dfla["Traffic_Calming"] = dfla["Traffic_Calming"].astype(int)
# Traffic_Signal
dfla["Traffic_Signal"] = dfla["Traffic_Signal"].astype(int)
# Turning_Loop
dfla["Turning_Loop"] = dfla["Turning_Loop"].astype(int)

print(dfla.dtypes)
print(dfla.tail())
# Out:
# Severity                   int64
# Start_Time                object
# Start_Lat                float64
# Start_Lng                float64
# Street                    object
# Side                      object
# City                      object
# County                    object
# State                     object
# Zipcode                   object
# Timezone                  object
# Temperature(F)           float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# Wind_Speed(mph)          float64
# Precipitation(in)        float64
# Weather_Condition         object
# Amenity                    int64
# Bump                       int64
# Crossing                   int64
# Give_Way                   int64
# Junction                   int64
# No_Exit                    int64
# Railway                    int64
# Roundabout                 int64
# Station                    int64
# Stop                       int64
# ...

# %% [markdown]
# Twilight! Day = 1 Night = 0

# %%
# Deprecated

# Sunrise_Sunset
#dfla["Sunrise_Sunset"]=dfla["Sunrise_Sunset"].replace("Day",0).replace("Night",1).astype(int)
# Astronomical_Twilight
#dfla["Astronomical_Twilight"]=dfla["Astronomical_Twilight"].replace("Day",0).replace("Night",1).astype(int)

#print(dfla.dtypes)
#print(dfla.tail())
# Out:
# Severity                   int64
# Start_Time                object
# Start_Lat                float64
# Start_Lng                float64
# Street                    object
# Side                      object
# City                      object
# County                    object
# State                     object
# Zipcode                   object
# Timezone                  object
# Temperature(F)           float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# Wind_Speed(mph)          float64
# Precipitation(in)        float64
# Weather_Condition         object
# Amenity                    int64
# Bump                       int64
# Crossing                   int64
# Give_Way                   int64
# Junction                   int64
# No_Exit                    int64
# Railway                    int64
# Roundabout                 int64
# Station                    int64
# Stop                       int64
# ...

# %%
# Create 3 columns to one-hot encode for day, twilight, and night

import numpy as np

#define a new column based on conditions:
#    day = 1 iff (Sunrise_Sunset == Day)
#    twilight = 1 iff (Sunrise_Sunset == Night && Astro_Twi == Day)
#    Night = 1 iff (Astro_Twi==Night )
#    
#    np.where(condition, value if condition is true, value if condition is false)
    
dfla["Day"] = np.where(dfla["Sunrise_Sunset"]=='Day', 1, 0)
dfla["Twilight"] = np.where(((dfla["Sunrise_Sunset"]=='Night') & (dfla["Astronomical_Twilight"]=='Day')), 1, 0)
dfla["Night"] = np.where(dfla["Astronomical_Twilight"]=='Night', 1, 0)

dfla.head()

# I actually should get rid of "Night" because it will be collinear with 'Day' and 'Twilight'
# Out:
# <ipython-input-60-8a1d3d346618>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfla["Day"] = np.where(dfla["Sunrise_Sunset"]=='Day', 1, 0)
# <ipython-input-60-8a1d3d346618>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfla["Twilight"] = np.where(((dfla["Sunrise_Sunset"]=='Night') & (dfla["Astronomical_Twilight"]=='Day')), 1, 0)
# <ipython-input-60-8a1d3d346618>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfla.drop(['Sunrise_Sunset','Astronomical_Twilight'], axis=1, inplace=True)
dfla.tail()
# Out:
# /Users/petermcmaster/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#          Severity           Start_Time  Start_Lat  Start_Lng           Street  \
# 3513295         2  2019-08-22 17:07:14   34.03693 -118.43877  San Diego Fwy S
# 3513703         3  2019-08-23 04:04:48   34.07579 -118.27668  Hollywood Fwy S
# 3513707         2  2019-08-23 12:52:31   34.02379 -118.27639     Harbor Fwy N
# 3513710         2  2019-08-23 13:42:50   34.07061 -118.26391  Hollywood Fwy S
# 3513722         2  2019-08-23 15:45:43   34.04365 -118.44373          I-405 N
#
#         Side         City       County State Zipcode    Timezone  \
# 3513295    R  Los Angeles  Los Angeles    CA   90064  US/Pacific
# ...

# %%
dfla["Weather_Condition"].value_counts()
# Out:
# Clear                           31691
# Fair                            16257
# Overcast                         6946
# Partly Cloudy                    5270
# Mostly Cloudy                    4776
# Cloudy                           4568
# Haze                             3923
# Light Rain                       2138
# Scattered Clouds                 1896
# Rain                              608
# Heavy Rain                        415
# Fog                               211
# Smoke                             100
# Mist                               28
# Patches of Fog                     18
# Fair / Windy                       11
# Blowing Dust                        5
# Light Drizzle                       4
# Light Rain / Windy                  4
# Shallow Fog                         3
# Thunderstorm                        2
# Mostly Cloudy / Windy               2
# Rain / Windy                        1
# Light Thunderstorms and Rain        1
# Light Rain with Thunder             1
# ...

# %%
# Group like weather together, basically just find rain.
clear_list=["Clear", "Fair","Overcast", "Partly Cloudy", "Mostly Cloudy",
           "Cloudy", "Haze", "Scattered Clouds", "Fog", "Smoke", "Mist", 
            "Patches of Fog", "Fair / Windy", "Blowing Dust", "Shallow Fog", 
            "Thunderstorm", "Mostly Cloudy / Windy", "Heavy T-Storm", "Thunder", 
            "Partly Cloudy / Windy"]

rain_list=["Light Rain", "Rain", "Heavy Rain", "Light Drizzle", 
           "Light Rain / Windy", "Rain / Windy", "Light Thunderstorms and Rain", 
           "Light Rain with Thunderstorm", "Drzzle"]

dfla["Rain"]=np.where(dfla["Weather_Condition"].isin(rain_list), 1, 0)
dfla.head()
# Out:
# <ipython-input-71-50ea34c1cb22>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfla["Rain"]=np.where(dfla["Weather_Condition"].isin(rain_list), 1, 0)
#        Severity           Start_Time  Start_Lat   Start_Lng  \
# 42866         2  2016-06-21 10:46:30  34.078926 -118.289040
# 42867         3  2016-06-21 10:49:21  34.091179 -118.239471
# 42881         3  2016-06-21 10:51:45  34.037239 -118.309074
# 42883         3  2016-06-21 10:56:24  34.027458 -118.274490
# 42898         3  2016-06-21 11:30:46  33.947544 -118.279434
#
#                    Street Side         City       County State Zipcode  \
# 42866            US-101 N    R  Los Angeles  Los Angeles    CA   90004
# ...

# %%
# Get rain one-hot coding for precipitation(in) > 0.10in
dfla["Rain>0.1"]=np.where(dfla["Precipitation(in)"] >= 0.1, 1, 0)
dfla.tail()
# Out:
# <ipython-input-73-bdeaedda3677>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfla["Rain>0.1"]=np.where(dfla["Precipitation(in)"] >= 0.1, 1, 0)
#          Severity           Start_Time  Start_Lat  Start_Lng           Street  \
# 3513295         2  2019-08-22 17:07:14   34.03693 -118.43877  San Diego Fwy S
# 3513703         3  2019-08-23 04:04:48   34.07579 -118.27668  Hollywood Fwy S
# 3513707         2  2019-08-23 12:52:31   34.02379 -118.27639     Harbor Fwy N
# 3513710         2  2019-08-23 13:42:50   34.07061 -118.26391  Hollywood Fwy S
# 3513722         2  2019-08-23 15:45:43   34.04365 -118.44373          I-405 N
#
#         Side         City       County State Zipcode    Timezone  \
# ...

# %%
dfla["Rain>0.1"].value_counts()
# Out:
# 0    78471
# 1      699
# Name: Rain>0.1, dtype: int64

# %%
dfla["Rain"].value_counts()
# Out:
# 0    75999
# 1     3171
# Name: Rain, dtype: int64

# %%
# One-hot for days

from datetime import datetime
from datetime import date

dfla["Start_Time"] = pd.to_datetime(dfla["Start_Time"], format="%Y-%m-%d %H:%M:%S")

dfla["dayofweek"]=dfla["Start_Time"].dt.dayofweek
dfla.tail(20)

# I used pd.to_datetime(data[], format='') instead of the deprecated datetime.strptime(data[], format)
# Out:
# <ipython-input-101-9285657a858b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfla["Start_Time"] = pd.to_datetime(dfla["Start_Time"], format="%Y-%m-%d %H:%M:%S")
# <ipython-input-101-9285657a858b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfla["dayofweek"]=dfla["Start_Time"].dt.dayofweek
#          Severity          Start_Time  Start_Lat   Start_Lng  \
# 3510685         2 2019-08-16 18:54:41  34.097720 -118.314140
# 3511160         3 2019-08-18 12:41:10  33.985547 -118.280610
# ...

# %%
# Violin Plot of dayofweek

plt.figure(figsize=(20,15))
#ax = sns.boxplot(x=dfla["dayofweek"], y=dfla["Severity"])
ax = sns.violinplot(x=dfla["dayofweek"], y=dfla["Severity"])

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

plt.plot(5,5,'ro')
plt.ylabel("Y")
plt.xlabel("X")
plt.title("Plotting Example")
plt.show()

#ax = dfla.plot(kind='bar',
#               width=0.8,
#              fontsize=14)

#ax.set_title("I have no ide", fontsize=16)
#ax.legend(fontsize=14)


#sns.boxplot(x="Precipitation(in)", hue="Severity",
#            palette="pastel", edgecolor=".6",
#           data=dfla)

# %%
# make a count column so we can count the occurrences of each Severity marker

dfla["count"]=np.where(True, 1, 1)
dfla.tail()
# Out:
# <ipython-input-113-e9e7e50691d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfla["count"]=np.where(True, 1, 1)
#          Severity          Start_Time  Start_Lat  Start_Lng           Street  \
# 3513295         2 2019-08-22 17:07:14   34.03693 -118.43877  San Diego Fwy S
# 3513703         3 2019-08-23 04:04:48   34.07579 -118.27668  Hollywood Fwy S
# 3513707         2 2019-08-23 12:52:31   34.02379 -118.27639     Harbor Fwy N
# 3513710         2 2019-08-23 13:42:50   34.07061 -118.26391  Hollywood Fwy S
# 3513722         2 2019-08-23 15:45:43   34.04365 -118.44373          I-405 N
#
#         Side         City       County State Zipcode    Timezone  \
# 3513295    R  Los Angeles  Los Angeles    CA   90064  US/Pacific
# ...

# %%
# Sanity Check: is it really not raining?

raincheck = dfla["Rain"].astype(bool)
print(raincheck)
print(dfla["Precipitation(in)"].notnull())

# good check! We need to change NaN values to 0.0
# Out:
# 42866      False
# 42867      False
# 42881      False
# 42883      False
# 42898      False
#            ...
# 3513295    False
# 3513703    False
# 3513707    False
# 3513710    False
# 3513722    False
# Name: Rain, Length: 79170, dtype: bool
# 42866      False
# 42867      False
# 42881      False
# 42883      False
# 42898      False
#            ...
# 3513295     True
# 3513703     True
# 3513707     True
# 3513710     True
# 3513722     True
# Name: Precipitation(in), Length: 79170, dtype: bool

# %%
dfla["Precipitation(in)"].isnull().value_counts()
# Out:
# True     47148
# False    32022
# Name: Precipitation(in), dtype: int64

# %%
# change NaN Values to 0.0

dfla["Precipitation(in)"] = dfla["Precipitation(in)"].where(dfla["Precipitation(in)"].notnull(), 0.0)
dfla.tail()
# Out:
# <ipython-input-119-b4105f28426a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfla["Precipitation(in)"] = dfla["Precipitation(in)"].where(dfla["Precipitation(in)"].notnull(), 0.0)
#          Severity          Start_Time  Start_Lat  Start_Lng           Street  \
# 3513295         2 2019-08-22 17:07:14   34.03693 -118.43877  San Diego Fwy S
# 3513703         3 2019-08-23 04:04:48   34.07579 -118.27668  Hollywood Fwy S
# 3513707         2 2019-08-23 12:52:31   34.02379 -118.27639     Harbor Fwy N
# 3513710         2 2019-08-23 13:42:50   34.07061 -118.26391  Hollywood Fwy S
# 3513722         2 2019-08-23 15:45:43   34.04365 -118.44373          I-405 N
#
#         Side         City       County State Zipcode    Timezone  \
# ...

# %%
dfla["Precipitation(in)"].isnull().value_counts()
# Out:
# False    79170
# Name: Precipitation(in), dtype: int64

# %%
dfla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79170 entries, 42866 to 3513722
# Data columns (total 39 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Severity           79170 non-null  int64
#  1   Start_Time         79170 non-null  datetime64[ns]
#  2   Start_Lat          79170 non-null  float64
#  3   Start_Lng          79170 non-null  float64
#  4   Street             79170 non-null  object
#  5   Side               79170 non-null  object
#  6   City               79170 non-null  object
#  7   County             79170 non-null  object
#  8   State              79170 non-null  object
#  9   Zipcode            79170 non-null  object
#  10  Timezone           79170 non-null  object
#  11  Temperature(F)     78738 non-null  float64
#  12  Humidity(%)        78706 non-null  float64
#  13  Pressure(in)       78854 non-null  float64
#  14  Visibility(mi)     78881 non-null  float64
# ...

# %%
# Plot the number of occurrences of dfla["Severity"]
dfla["Severity"].value_counts().plot(kind='bar')

# %%
PROBLEM>>> I want the value counts seies data on the y-axis, 0-6 for days on the x-axis, 
and for those value_counts to be grouped by severity... BUT I CAN'T DO IT!'

#sns.catplot(
#    data=dfla,
#    x='dayofweek',
#    y=dfla["Severity"].value_counts(),
#    hue='Severity')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-110-f4a45c4c35ce> in <module>
# ----> 1 sns.catplot(
#       2     data=dfla,
#       3     x='dayofweek',
#       4     y=dfla["Severity"].value_counts(),
#       5     hue='Severity')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3760
#    3761     # Draw the plot onto the facets
# -> 3762     g.map_dataframe(plot_func, x, y, hue, **plot_kws)
#    3763
#    3764     # Special case axis labels for a count type plot
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     826
# ...

# %%
print(dfla["ID"][dfla["Side"]=="L"].count())
# Out:
# 8995

# %%
print(dfla["Severity"])
# Out:
# 42866      2
# 42867      3
# 42881      3
# 42883      3
# 42898      3
#           ..
# 3513295    2
# 3513703    3
# 3513707    2
# 3513710    2
# 3513722    2
# Name: Severity, Length: 79170, dtype: int64

# %%
Rcount = dfla

ax = dfla.plot(kind='bar',
               width=0.8,
              fontsize=14)

# %%
# make a multi-bar plot with 
# count on y-axis
# precipitation on x-axis
# severity represented by different bars

import seaborn as sns
import matplotlib.pyplot as plt

fig_dims=(14,10)

fig, ax = plt.subplots(figsize=fig_dims)

sns.catplot(x="Precipitation(in)", hue="Severity", kind="count", log=True,
            palette="pastel", edgecolor=".6",
            ax=ax, data=data)
# Out:
# /Users/petermcmaster/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)

# %%
import numpy as np

# Create a Table to ID nulls

def missing_data(data):
    # Count number of missing values in a column
    total = data.isnull().sum()
    
    # Get Percentage of missing values
    percent = (data.isnull().sum()/data.isnull().count()*100)
    temp = pd.concat([total, percent], axis=1, keys=['Total','Percent(%)'])
    
    # Create a Type column, that indicates the data-type of the column.
    types = []
    for col in data.columns:
        dtype = str(data[col].dtype)
        types.append(dtype)
    temp['Types'] = types
    
    return(np.transpose(temp))

missing_data(data)
# Out:
#                 ID  Source      TMC Severity Start_Time End_Time Start_Lat  \
# Total            0       0  1034922        0          0        0         0
# Percent(%)       0       0  29.4536        0          0        0         0
# Types       object  object  float64    int64     object   object   float64
#
#            Start_Lng  End_Lat  End_Lng Distance(mi)  Description   Number  \
# Total              0  2478818  2478818            0            1  2262954
# Percent(%)         0  70.5464  70.5464            0  2.84597e-05   64.403
# Types        float64  float64  float64      float64       object  float64
#
#             Street    Side        City  County   State    Zipcode Country  \
# Total            0       0         112       0       0       1069       0
# Percent(%)       0       0  0.00318749       0       0  0.0304234       0
# Types       object  object      object  object  object     object  object
#
# ...

# %%
# Date and Time Methods

from datetime import datetime
from datetime import date

print(data['Start_Time'])

my_date = datetime.strptime(data['Start_Time'], "%Y-%m-%d %H:%M:%S")
print(my_date)
print(my_date.weekday())
# Out:
# 0          2016-02-08 05:46:00
# 1          2016-02-08 06:07:59
# 2          2016-02-08 06:49:27
# 3          2016-02-08 07:23:34
# 4          2016-02-08 07:39:07
#                   ...
# 3513735    2019-08-23 18:03:25
# 3513736    2019-08-23 19:11:30
# 3513737    2019-08-23 19:00:21
# 3513738    2019-08-23 19:00:21
# 3513739    2019-08-23 18:52:06
# Name: Start_Time, Length: 3513740, dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-b3f88c8449ec> in <module>
#       6 print(data['Start_Time'])
#       7
# ----> 8 my_date = datetime.strptime(data['Start_Time'], "%Y-%m-%d %H:%M:%S")
#       9 print(my_date)
#      10 print(my_date.weekday())
#
# TypeError: strptime() argument 1 must be str, not Series

# %%
import datetime

raw_data['Mycol'] =  pd.to_datetime(raw_data['Mycol'], format='%d%b%Y:%H:%M:%S.%f')

my_dates = dfla["Start_Time"].astype(datetime64)
print(my_dates)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-f556c6a22e2b> in <module>
#       2
#       3
# ----> 4 my_dates = dfla["Start_Time"].astype(datetime64)
#       5 print(my_dates)
#
# NameError: name 'datetime64' is not defined

# %%
# Peep dtypes
data.dtypes
# Out:
# ID                        object
# Source                    object
# TMC                      float64
# Severity                   int64
# Start_Time                object
# End_Time                  object
# Start_Lat                float64
# Start_Lng                float64
# End_Lat                  float64
# End_Lng                  float64
# Distance(mi)             float64
# Description               object
# Number                   float64
# Street                    object
# Side                      object
# City                      object
# County                    object
# State                     object
# Zipcode                   object
# Country                   object
# Timezone                  object
# Airport_Code              object
# Weather_Timestamp         object
# Temperature(F)           float64
# Wind_Chill(F)            float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# ...

# %%
# Peep COuntry
data['Country'].value_counts()
# Out:
# US    3513740
# Name: Country, dtype: int64

# %%
# Peep them Disktances
data['Distance(mi)'].value_counts()
# Out:
# 0.000     2457182
# 0.010      250988
# 0.010       13359
# 0.020        5968
# 0.001        5528
#            ...
# 9.356           1
# 7.967           1
# 9.269           1
# 6.688           1
# 16.911          1
# Name: Distance(mi), Length: 13476, dtype: int64

# %%
# Peep those descriptions

descriptions = data['Description']
pd.set_option('max_colwidth', None)
descriptions.head(40)
# Out:
# 0                     Right lane blocked due to accident on I-70 Eastbound at Exit 41 OH-235 State Route 4.
# 1                                                        Accident on Brice Rd at Tussing Rd. Expect delays.
# 2                               Accident on OH-32 State Route 32 Westbound at Dela Palma Rd. Expect delays.
# 3                                         Accident on I-75 Southbound at Exits 52 52B US-35. Expect delays.
# 4                                 Accident on McEwen Rd at OH-725 Miamisburg Centerville Rd. Expect delays.
# 5                         Accident on I-270 Outerbelt Northbound near Exit 29 OH-3 State St. Expect delays.
# 6                                                   Accident on Oakridge Dr at Woodward Ave. Expect delays.
# 7                                         Accident on I-75 Southbound at Exit 54B Grand Ave. Expect delays.
# 8                                                  Accident on Notre Dame Ave at Warner Ave. Expect delays.
# ...

# %%
# Peep those TMC reports
TMC = data['TMC'].value_counts()
print(TMC)
# Out:
# 201.0    2080341
# 241.0     249852
# 245.0      40338
# 229.0      22932
# 203.0      17639
# 222.0      13154
# 244.0      12185
# 406.0      11109
# 246.0       7118
# 343.0       6930
# 202.0       6298
# 247.0       4775
# 236.0       2121
# 206.0       1274
# 248.0       1025
# 339.0        920
# 341.0        592
# 336.0         89
# 200.0         66
# 239.0         54
# 351.0          6
# Name: TMC, dtype: int64

# %%
import numpy as np

# Create a Table which displays column name, number of null values, percentage of null values, and dtype

def missing_data(data):
    # Count number of missing values in a column
    total = data.isnull().sum()
    
    # Get Percentage of missing values
    percent = (data.isnull().sum()/data.isnull().count()*100)
    temp = pd.concat([total, percent], axis=1, keys=['Total','Percent(%)'])
    
    # Create a Type column, that indicates the data-type of the column.
    types = []
    for col in data.columns:
        dtype = str(data[col].dtype)
        types.append(dtype)
    temp['Types'] = types
    
    return(np.transpose(temp))

missing_data(data)
# Out:
#                 ID  Source      TMC Severity Start_Time End_Time Start_Lat  \
# Total            0       0  1034922        0          0        0         0
# Percent(%)       0       0  29.4536        0          0        0         0
# Types       object  object  float64    int64     object   object   float64
#
#            Start_Lng  End_Lat  End_Lng Distance(mi)  Description   Number  \
# Total              0  2478818  2478818            0            1  2262954
# Percent(%)         0  70.5464  70.5464            0  2.84597e-05   64.403
# Types        float64  float64  float64      float64       object  float64
#
#             Street    Side        City  County   State    Zipcode Country  \
# Total            0       0         112       0       0       1069       0
# Percent(%)       0       0  0.00318749       0       0  0.0304234       0
# Types       object  object      object  object  object     object  object
#
# ...

# %%
# exploring Weather_Conditions

print(len(pd.unique(data['Weather_Condition'])))
pd.unique(data['Weather_Condition'])
# Out:
# 128
# array(['Light Rain', 'Overcast', 'Mostly Cloudy', 'Rain', 'Light Snow',
#        'Haze', 'Scattered Clouds', 'Partly Cloudy', 'Clear', 'Snow',
#        'Light Freezing Drizzle', 'Light Drizzle', 'Fog', 'Shallow Fog',
#        'Heavy Rain', 'Light Freezing Rain', 'Cloudy', 'Drizzle', nan,
#        'Light Rain Showers', 'Mist', 'Smoke', 'Patches of Fog',
#        'Light Freezing Fog', 'Light Haze', 'Light Thunderstorms and Rain',
#        'Thunderstorms and Rain', 'Fair', 'Volcanic Ash', 'Blowing Sand',
#        'Blowing Dust / Windy', 'Widespread Dust', 'Fair / Windy',
#        'Rain Showers', 'Mostly Cloudy / Windy', 'Light Rain / Windy',
#        'Hail', 'Heavy Drizzle', 'Showers in the Vicinity', 'Thunderstorm',
#        'Light Rain Shower', 'Light Rain with Thunder',
#        'Partly Cloudy / Windy', 'Thunder in the Vicinity', 'T-Storm',
#        'Heavy Thunderstorms and Rain', 'Thunder', 'Heavy T-Storm',
#        'Funnel Cloud', 'Heavy T-Storm / Windy', 'Blowing Snow',
# ...

# %%
# Exploring occurences by state
state = data['State'].value_counts()
print(state)
# Out:
# CA    816826
# TX    329284
# FL    258002
# SC    173277
# NC    165963
# NY    160817
# PA    106794
# IL     99692
# VA     96075
# MI     95983
# GA     93614
# OR     90134
# MN     81865
# AZ     78586
# TN     69895
# WA     68545
# OH     66140
# LA     61515
# OK     60003
# NJ     59059
# MD     53593
# UT     51685
# CO     49731
# AL     44625
# MA     39044
# IN     33752
# MO     33643
# CT     25901
# NE     23971
# KY     22553
# WI     20120
# RI     11753
# IA     11475
# NV     10724
# NH      7984
# KS      7939
# MS      6585
# DE      5739
# NM      5523
# DC      4820
# WV      2381
# ME      2243
# ID      2048
# AR      2012
# VT       702
# MT       512
# WY       508
# SD        61
# ND        44
# Name: State, dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# ### Maps

# %% [markdown]
# ### Feature Set

# %% [markdown]
# ### Train Test Split

# %% [markdown]
# ### Normalize the Data

# %% [markdown]
# ### Plots

# %% [markdown]
# ### Machine Learning Models

# %% [markdown]
# ### Results, Evaluations, and Discussion

# %% [markdown]
# ### Conclusion and Recommendation
